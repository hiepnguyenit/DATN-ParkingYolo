# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import glob
import os

os.chdir("/content/gdrive/MyDrive/ML/darknet")
# Directory of images to run detection on
ROOT_DIR = os.getcwd()
print(ROOT_DIR)
# Out:
# /content/gdrive/MyDrive/ML/darknet

# %%
# !sudo apt install dos2unix
# !dos2unix cfg/yolov3.cfg train.txt val.txt coco.names coco.data
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# dos2unix is already the newest version (7.3.4-3).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.
# dos2unix: converting file cfg/yolov3.cfg to Unix format...
# dos2unix: converting file train.txt to Unix format...
# dos2unix: converting file val.txt to Unix format...
# dos2unix: converting file coco.names to Unix format...
# dos2unix: converting file coco.data to Unix format...

# %%
# !make clean
# Out:
# rm -rf ./obj/gemm.o ./obj/utils.o ./obj/cuda.o ./obj/deconvolutional_layer.o ./obj/convolutional_layer.o ./obj/list.o ./obj/image.o ./obj/activations.o ./obj/im2col.o ./obj/col2im.o ./obj/blas.o ./obj/crop_layer.o ./obj/dropout_layer.o ./obj/maxpool_layer.o ./obj/softmax_layer.o ./obj/data.o ./obj/matrix.o ./obj/network.o ./obj/connected_layer.o ./obj/cost_layer.o ./obj/parser.o ./obj/option_list.o ./obj/detection_layer.o ./obj/route_layer.o ./obj/upsample_layer.o ./obj/box.o ./obj/normalization_layer.o ./obj/avgpool_layer.o ./obj/layer.o ./obj/local_layer.o ./obj/shortcut_layer.o ./obj/logistic_layer.o ./obj/activation_layer.o ./obj/rnn_layer.o ./obj/gru_layer.o ./obj/crnn_layer.o ./obj/demo.o ./obj/batchnorm_layer.o ./obj/region_layer.o ./obj/reorg_layer.o ./obj/tree.o ./obj/lstm_layer.o ./obj/l2norm_layer.o ./obj/yolo_layer.o ./obj/iseg_layer.o ./obj/image_opencv.o ./obj/convolutional_kernels.o ./obj/deconvolutional_kernels.o ./obj/activation_kernels.o ./obj/im2col_kernels.o ./obj
# ...

# %%
# !make
# Out:
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# gcc -Iinclude/ -Isrc/ -DGPU -I/usr/local/cuda/include/ -DCUDNN  -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DGPU -DCUDNN -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘time_gpu’:
# ./src/gemm.c:232:9: warning: ‘cudaThreadSynchronize’ is deprecated [-Wdeprecated-declarations]
#          cudaThreadSynchronize();
#          ^~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:11,
#                  from ./src/utils.h:5,
#                  from ./src/gemm.c:2:
# /usr/local/cuda/include/cuda_runtime_api.h:967:57: note: declared here
#  extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaThreadSynchronize(void);
#                                                          ^~~~~~~~~~~~~~~~~~~~~
# ...

# %%
# !chmod +x ./darknet

# %%
# !./darknet detector train coco.data cfg/yolov3.cfg darknet53.conv.74 > yolov3-5c.log
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   640 x 640 x   3   ->   640 x 640 x  32  0.708 BFLOPs
#     1 conv     64  3 x 3 / 2   640 x 640 x  32   ->   320 x 320 x  64  3.775 BFLOPs
#     2 conv     32  1 x 1 / 1   320 x 320 x  64   ->   320 x 320 x  32  0.419 BFLOPs
#     3 conv     64  3 x 3 / 1   320 x 320 x  32   ->   320 x 320 x  64  3.775 BFLOPs
#     4 res    1                 320 x 320 x  64   ->   320 x 320 x  64
#     5 conv    128  3 x 3 / 2   320 x 320 x  64   ->   160 x 160 x 128  3.775 BFLOPs
#     6 conv     64  1 x 1 / 1   160 x 160 x 128   ->   160 x 160 x  64  0.419 BFLOPs
#     7 conv    128  3 x 3 / 1   160 x 160 x  64   ->   160 x 160 x 128  3.775 BFLOPs
#     8 res    5                 160 x 160 x 128   ->   160 x 160 x 128
#     9 conv     64  1 x 1 / 1   160 x 160 x 128   ->   160 x 160 x  64  0.419 BFLOPs
#    10 conv    128  3 x 3 / 1   160 x 160 x  64   ->   160 x 160 x 128  3.775 BFLOPs
# ...

# %%
# !./darknet detector train coco.data cfg/yolov3.cfg backup/yolov3_900.weights > yolov3-5c.log
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   640 x 640 x   3   ->   640 x 640 x  32  0.708 BFLOPs
#     1 conv     64  3 x 3 / 2   640 x 640 x  32   ->   320 x 320 x  64  3.775 BFLOPs
#     2 conv     32  1 x 1 / 1   320 x 320 x  64   ->   320 x 320 x  32  0.419 BFLOPs
#     3 conv     64  3 x 3 / 1   320 x 320 x  32   ->   320 x 320 x  64  3.775 BFLOPs
#     4 res    1                 320 x 320 x  64   ->   320 x 320 x  64
#     5 conv    128  3 x 3 / 2   320 x 320 x  64   ->   160 x 160 x 128  3.775 BFLOPs
#     6 conv     64  1 x 1 / 1   160 x 160 x 128   ->   160 x 160 x  64  0.419 BFLOPs
#     7 conv    128  3 x 3 / 1   160 x 160 x  64   ->   160 x 160 x 128  3.775 BFLOPs
#     8 res    5                 160 x 160 x 128   ->   160 x 160 x 128
#     9 conv     64  1 x 1 / 1   160 x 160 x 128   ->   160 x 160 x  64  0.419 BFLOPs
#    10 conv    128  3 x 3 / 1   160 x 160 x  64   ->   160 x 160 x 128  3.775 BFLOPs
# ...

# %%
# !./darknet detector train coco.data cfg/yolov3.cfg backup/yolov3.backup > yolov3-5c.log
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   640 x 640 x   3   ->   640 x 640 x  32  0.708 BFLOPs
#     1 conv     64  3 x 3 / 2   640 x 640 x  32   ->   320 x 320 x  64  3.775 BFLOPs
#     2 conv     32  1 x 1 / 1   320 x 320 x  64   ->   320 x 320 x  32  0.419 BFLOPs
#     3 conv     64  3 x 3 / 1   320 x 320 x  32   ->   320 x 320 x  64  3.775 BFLOPs
#     4 res    1                 320 x 320 x  64   ->   320 x 320 x  64
#     5 conv    128  3 x 3 / 2   320 x 320 x  64   ->   160 x 160 x 128  3.775 BFLOPs
#     6 conv     64  1 x 1 / 1   160 x 160 x 128   ->   160 x 160 x  64  0.419 BFLOPs
#     7 conv    128  3 x 3 / 1   160 x 160 x  64   ->   160 x 160 x 128  3.775 BFLOPs
#     8 res    5                 160 x 160 x 128   ->   160 x 160 x 128
#     9 conv     64  1 x 1 / 1   160 x 160 x 128   ->   160 x 160 x  64  0.419 BFLOPs
#    10 conv    128  3 x 3 / 1   160 x 160 x  64   ->   160 x 160 x 128  3.775 BFLOPs
# ...

# %%
# !./darknet detector train coco.data cfg/yolov3.cfg backup/yolov3_2000.weights > yolov3-5c1.log
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   640 x 640 x   3   ->   640 x 640 x  32  0.708 BFLOPs
#     1 conv     64  3 x 3 / 2   640 x 640 x  32   ->   320 x 320 x  64  3.775 BFLOPs
#     2 conv     32  1 x 1 / 1   320 x 320 x  64   ->   320 x 320 x  32  0.419 BFLOPs
#     3 conv     64  3 x 3 / 1   320 x 320 x  32   ->   320 x 320 x  64  3.775 BFLOPs
#     4 res    1                 320 x 320 x  64   ->   320 x 320 x  64
#     5 conv    128  3 x 3 / 2   320 x 320 x  64   ->   160 x 160 x 128  3.775 BFLOPs
#     6 conv     64  1 x 1 / 1   160 x 160 x 128   ->   160 x 160 x  64  0.419 BFLOPs
#     7 conv    128  3 x 3 / 1   160 x 160 x  64   ->   160 x 160 x 128  3.775 BFLOPs
#     8 res    5                 160 x 160 x 128   ->   160 x 160 x 128
#     9 conv     64  1 x 1 / 1   160 x 160 x 128   ->   160 x 160 x  64  0.419 BFLOPs
#    10 conv    128  3 x 3 / 1   160 x 160 x  64   ->   160 x 160 x 128  3.775 BFLOPs
# ...

# %%
# !./darknet detector train coco.data cfg/yolov3.cfg backup/yolov3.backup > yolov3-5c2.log

# %%
# !./darknet detector train coco.data cfg/yolov3.cfg backup/yolov3.backup > yolov3-5c4.log
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   640 x 640 x   3   ->   640 x 640 x  32  0.708 BFLOPs
#     1 conv     64  3 x 3 / 2   640 x 640 x  32   ->   320 x 320 x  64  3.775 BFLOPs
#     2 conv     32  1 x 1 / 1   320 x 320 x  64   ->   320 x 320 x  32  0.419 BFLOPs
#     3 conv     64  3 x 3 / 1   320 x 320 x  32   ->   320 x 320 x  64  3.775 BFLOPs
#     4 res    1                 320 x 320 x  64   ->   320 x 320 x  64
#     5 conv    128  3 x 3 / 2   320 x 320 x  64   ->   160 x 160 x 128  3.775 BFLOPs
#     6 conv     64  1 x 1 / 1   160 x 160 x 128   ->   160 x 160 x  64  0.419 BFLOPs
#     7 conv    128  3 x 3 / 1   160 x 160 x  64   ->   160 x 160 x 128  3.775 BFLOPs
#     8 res    5                 160 x 160 x 128   ->   160 x 160 x 128
#     9 conv     64  1 x 1 / 1   160 x 160 x 128   ->   160 x 160 x  64  0.419 BFLOPs
#    10 conv    128  3 x 3 / 1   160 x 160 x  64   ->   160 x 160 x 128  3.775 BFLOPs
# ...

# %%
# !./darknet detector train coco.data cfg/yolov3.cfg backup/yolov3.backup > yolov3-5c4.log
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   640 x 640 x   3   ->   640 x 640 x  32  0.708 BFLOPs
#     1 conv     64  3 x 3 / 2   640 x 640 x  32   ->   320 x 320 x  64  3.775 BFLOPs
#     2 conv     32  1 x 1 / 1   320 x 320 x  64   ->   320 x 320 x  32  0.419 BFLOPs
#     3 conv     64  3 x 3 / 1   320 x 320 x  32   ->   320 x 320 x  64  3.775 BFLOPs
#     4 res    1                 320 x 320 x  64   ->   320 x 320 x  64
#     5 conv    128  3 x 3 / 2   320 x 320 x  64   ->   160 x 160 x 128  3.775 BFLOPs
#     6 conv     64  1 x 1 / 1   160 x 160 x 128   ->   160 x 160 x  64  0.419 BFLOPs
#     7 conv    128  3 x 3 / 1   160 x 160 x  64   ->   160 x 160 x 128  3.775 BFLOPs
#     8 res    5                 160 x 160 x 128   ->   160 x 160 x 128
#     9 conv     64  1 x 1 / 1   160 x 160 x 128   ->   160 x 160 x  64  0.419 BFLOPs
#    10 conv    128  3 x 3 / 1   160 x 160 x  64   ->   160 x 160 x 128  3.775 BFLOPs
# ...

# %%
# !./darknet detector train coco.data cfg/yolov3.cfg backup/yolov3.backup > yolov3-5c5.log
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   640 x 640 x   3   ->   640 x 640 x  32  0.708 BFLOPs
#     1 conv     64  3 x 3 / 2   640 x 640 x  32   ->   320 x 320 x  64  3.775 BFLOPs
#     2 conv     32  1 x 1 / 1   320 x 320 x  64   ->   320 x 320 x  32  0.419 BFLOPs
#     3 conv     64  3 x 3 / 1   320 x 320 x  32   ->   320 x 320 x  64  3.775 BFLOPs
#     4 res    1                 320 x 320 x  64   ->   320 x 320 x  64
#     5 conv    128  3 x 3 / 2   320 x 320 x  64   ->   160 x 160 x 128  3.775 BFLOPs
#     6 conv     64  1 x 1 / 1   160 x 160 x 128   ->   160 x 160 x  64  0.419 BFLOPs
#     7 conv    128  3 x 3 / 1   160 x 160 x  64   ->   160 x 160 x 128  3.775 BFLOPs
#     8 res    5                 160 x 160 x 128   ->   160 x 160 x 128
#     9 conv     64  1 x 1 / 1   160 x 160 x 128   ->   160 x 160 x  64  0.419 BFLOPs
#    10 conv    128  3 x 3 / 1   160 x 160 x  64   ->   160 x 160 x 128  3.775 BFLOPs
# ...

# %%
# !./darknet detector train coco.data cfg/yolov3.cfg backup/yolov3.backup > yolov3-5c6.log
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   640 x 640 x   3   ->   640 x 640 x  32  0.708 BFLOPs
#     1 conv     64  3 x 3 / 2   640 x 640 x  32   ->   320 x 320 x  64  3.775 BFLOPs
#     2 conv     32  1 x 1 / 1   320 x 320 x  64   ->   320 x 320 x  32  0.419 BFLOPs
#     3 conv     64  3 x 3 / 1   320 x 320 x  32   ->   320 x 320 x  64  3.775 BFLOPs
#     4 res    1                 320 x 320 x  64   ->   320 x 320 x  64
#     5 conv    128  3 x 3 / 2   320 x 320 x  64   ->   160 x 160 x 128  3.775 BFLOPs
#     6 conv     64  1 x 1 / 1   160 x 160 x 128   ->   160 x 160 x  64  0.419 BFLOPs
#     7 conv    128  3 x 3 / 1   160 x 160 x  64   ->   160 x 160 x 128  3.775 BFLOPs
#     8 res    5                 160 x 160 x 128   ->   160 x 160 x 128
#     9 conv     64  1 x 1 / 1   160 x 160 x 128   ->   160 x 160 x  64  0.419 BFLOPs
#    10 conv    128  3 x 3 / 1   160 x 160 x  64   ->   160 x 160 x 128  3.775 BFLOPs
# ...

# %%
# !./darknet detector train coco.data cfg/yolov3.cfg backup/yolov3.backup > yolov3-5c7.log
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   640 x 640 x   3   ->   640 x 640 x  32  0.708 BFLOPs
#     1 conv     64  3 x 3 / 2   640 x 640 x  32   ->   320 x 320 x  64  3.775 BFLOPs
#     2 conv     32  1 x 1 / 1   320 x 320 x  64   ->   320 x 320 x  32  0.419 BFLOPs
#     3 conv     64  3 x 3 / 1   320 x 320 x  32   ->   320 x 320 x  64  3.775 BFLOPs
#     4 res    1                 320 x 320 x  64   ->   320 x 320 x  64
#     5 conv    128  3 x 3 / 2   320 x 320 x  64   ->   160 x 160 x 128  3.775 BFLOPs
#     6 conv     64  1 x 1 / 1   160 x 160 x 128   ->   160 x 160 x  64  0.419 BFLOPs
#     7 conv    128  3 x 3 / 1   160 x 160 x  64   ->   160 x 160 x 128  3.775 BFLOPs
#     8 res    5                 160 x 160 x 128   ->   160 x 160 x 128
#     9 conv     64  1 x 1 / 1   160 x 160 x 128   ->   160 x 160 x  64  0.419 BFLOPs
#    10 conv    128  3 x 3 / 1   160 x 160 x  64   ->   160 x 160 x 128  3.775 BFLOPs
# ...

# %%
# !./darknet detector train coco.data cfg/yolov3.cfg backup/yolov3.backup > yolov3-5c8.log
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   640 x 640 x   3   ->   640 x 640 x  32  0.708 BFLOPs
#     1 conv     64  3 x 3 / 2   640 x 640 x  32   ->   320 x 320 x  64  3.775 BFLOPs
#     2 conv     32  1 x 1 / 1   320 x 320 x  64   ->   320 x 320 x  32  0.419 BFLOPs
#     3 conv     64  3 x 3 / 1   320 x 320 x  32   ->   320 x 320 x  64  3.775 BFLOPs
#     4 res    1                 320 x 320 x  64   ->   320 x 320 x  64
#     5 conv    128  3 x 3 / 2   320 x 320 x  64   ->   160 x 160 x 128  3.775 BFLOPs
#     6 conv     64  1 x 1 / 1   160 x 160 x 128   ->   160 x 160 x  64  0.419 BFLOPs
#     7 conv    128  3 x 3 / 1   160 x 160 x  64   ->   160 x 160 x 128  3.775 BFLOPs
#     8 res    5                 160 x 160 x 128   ->   160 x 160 x 128
#     9 conv     64  1 x 1 / 1   160 x 160 x 128   ->   160 x 160 x  64  0.419 BFLOPs
#    10 conv    128  3 x 3 / 1   160 x 160 x  64   ->   160 x 160 x 128  3.775 BFLOPs
# ...

# %%
# !./darknet detector valid coco.data cfg/yolov3.cfg backup/yolov3_final.weights
# Out:
# results: Using default 'results'
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   640 x 640 x   3   ->   640 x 640 x  32  0.708 BFLOPs
#     1 conv     64  3 x 3 / 2   640 x 640 x  32   ->   320 x 320 x  64  3.775 BFLOPs
#     2 conv     32  1 x 1 / 1   320 x 320 x  64   ->   320 x 320 x  32  0.419 BFLOPs
#     3 conv     64  3 x 3 / 1   320 x 320 x  32   ->   320 x 320 x  64  3.775 BFLOPs
#     4 res    1                 320 x 320 x  64   ->   320 x 320 x  64
#     5 conv    128  3 x 3 / 2   320 x 320 x  64   ->   160 x 160 x 128  3.775 BFLOPs
#     6 conv     64  1 x 1 / 1   160 x 160 x 128   ->   160 x 160 x  64  0.419 BFLOPs
#     7 conv    128  3 x 3 / 1   160 x 160 x  64   ->   160 x 160 x 128  3.775 BFLOPs
#     8 res    5                 160 x 160 x 128   ->   160 x 160 x 128
#     9 conv     64  1 x 1 / 1   160 x 160 x 128   ->   160 x 160 x  64  0.419 BFLOPs
# ...
